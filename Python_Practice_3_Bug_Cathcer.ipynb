# %% [markdown]
# <a href="https://colab.research.google.com/github/sksguswjd717/Python-Practice/blob/main/Python_Practice_3_Bug_Cathcer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
butterflies = 10
beetles = 12
ladybugs = 20

print('I caught ' + butterflies + ' 🦋 butterflies!')
print('I caught ' + beetles + ' 🪲 beetles!')
print('I caught ' + ladybug + ' 🐞 ladybugs!)

print('I caught ' + str(total) + ' total bugs!'
'''

'''
File "/tmp/ipython-input-821540083.py", line 7
    print('I caught ' + ladybug + ' 🐞 ladybugs!)
                                  ^
SyntaxError: unterminated string literal (detected at line 7)
'''
butterflies = 10
beetles = 12
ladybugs = 20

print('I caught ' + str(butterflies) + ' 🦋 butterflies!')
print('I caught ' + str(beetles) + ' 🪲 beetles!')
print('I caught ' + str(ladybugs) + '🐞 ladybugs!')

total = butterflies + beetles + ladybugs

print('I caught ' + str(total) + ' total bugs!')
# Out:
# I caught 10 🦋 butterflies!
# I caught 12 🪲 beetles!
# I caught 20🐞 ladybugs!
# I caught 42 total bugs!
