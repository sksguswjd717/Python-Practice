# %%
#username = input('Enter your name = ')
#print(username)

#age = int(input('What is your age? '))
#print(age)
#int make result interger, not text


a = int(input('what is length of a side : '))
b = int(input('what is length of b side : '))
c = (a**2 + b**2)**(1/2)
print(c)
# Out:
# what is length of a side : 3
# what is length of b side : 4
# 5.0
